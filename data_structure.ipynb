# %% [markdown]
# <a href="https://colab.research.google.com/github/ponneeswari005-boop/Data--structure/blob/main/data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
players = ["Player 1", "Player 2", "Player 3"]

index = 0

for i in range(6):
    print("Turn:", players[index])
    index = (index + 1) % len(players)
# Out:
# Turn: Player 1
# Turn: Player 2
# Turn: Player 3
# Turn: Player 1
# Turn: Player 2
# Turn: Player 3

# %%
pages = ["Google", "YouTube", "Gmail"]
current = 1

print("Current:", pages[current])

current -= 1
print("Back:", pages[current])

current += 1
print("Forward:", pages[current])
# Out:
# Current: YouTube
# Back: Google
# Forward: YouTube
